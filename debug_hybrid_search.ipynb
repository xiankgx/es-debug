# %%
# !pip install elasticsearch numpy pandas tqdm

# %% [markdown]
# ### Imports

# %%
import json

import numpy as np
import pandas as pd

from elasticsearch import Elasticsearch

# %% [markdown]
# ### Instantiate Elasticsearch client

# %%
es = Elasticsearch(['http://localhost:9200/'])
es.ping()
# Out:
# True

# %% [markdown]
# ### Create index

# %%
INDEX_NAME = "image-index"

# %%
# Delete existing index
# !curl -X DELETE "localhost:9200/{INDEX_NAME}?pretty"
# Out:
# {
#   "acknowledged" : true
# }

# %%
resp = es.indices.create(
    index=INDEX_NAME, 
    mappings={
        "properties": {
            "download_count": {
                "type": "float"
            },
            
            "image_vector": {
                "type": "dense_vector",
                "dims": 512,
                "index": True,
                "similarity": "cosine"
            },
        }
    }
)
resp
# Out:
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'image-index'})

# %% [markdown]
# ### Add data

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

# %%
len(dataset)
# Out:
# 20000

# %%
dataset[0]
# Out:
# {'download_count': 10.0,
#  'image_vector': [0.4687531590461731,
#   1.858910083770752,
#   0.2487410604953766,
#   0.4361421465873718,
#   0.06379887461662292,
#   -0.6228192448616028,
#   -0.27867400646209717,
#   0.04752945899963379,
#   0.048252467066049576,
#   -0.6161901950836182,
#   -0.08333898335695267,
#   -0.178070068359375,
#   0.4829390347003937,
#   -0.051558591425418854,
#   -0.7764784693717957,
#   0.11730130016803741,
#   -0.9347928166389465,
#   0.4606996774673462,
#   0.17599976062774658,
#   0.12078317999839783,
#   -0.289231538772583,
#   0.35409796237945557,
#   0.022205233573913574,
#   -0.3168144226074219,
#   -0.3422653079032898,
#   0.5762258172035217,
#   -0.34303778409957886,
#   0.2701375484466553,
#   0.4523313641548157,
#   -0.07710081338882446,
#   -0.4255029559135437,
#   0.36728641390800476,
#   -0.39734968543052673,
#   -0.2473088502883911,
#   -0.07855471968650818,
#   0.2128201574087143,
#   0.06932312250137329,
#   0.05761660635471344,
#   0.23390062153339386,
#   -0.36632591485977173,
#   0.4863947629928589,
#   0.05075046792626381,
#   0.11290210485458374,
#   0.28760045766830444,
#   -0.2308099865913391,
#   -0.0017115715891122818,
#   -0.8445484638214111,
#   0.030514538288116455,
#   -0.07789520919322968,
#   0.19870901107788086,
#   -0.44095006585121155,
#   0.8912190198898315,
#   -0.15201900899410248,
#   0.10636603087186813,
#   0.027862638235092163,
#   -0.0004918724298477173,
#   0.029951587319374084,
#   -0.3201911747455597,
#   -0.024078786373138428,
#   0.38028228282928467,
#   0.9459820985794067,
#   0.7422810792922974,
#   -0.24635112285614014,
#   -0.10885198414325714,
#   -0.30865445733070374,
#   0.13384637236595154,
#   -0.42629140615463257,
#   1.4339044094085693,
#   -0.5605570673942566,
#   -0.3910380005836487,
#   -0.3441806435585022,
#   0.3214077055454254,
#   0.10151407122612,
#   1.2528929710388184,
#   -0.29751235246658325,
#   0.46046727895736694,
#   -0.599770188331604,
#   0.22962351143360138,
#   0.002256333827972412,
#   -0.16893300414085388,
#   -0.3684174120426178,
#   -0.23994283378124237,
#   0.21570304036140442,
#   -0.25261637568473816,
#   0.741874098777771,
#   0.1942327916622162,
#   -0.2722105085849762,
#   -0.18331192433834076,
#   -0.029642164707183838,
#   0.27085375785827637,
#   0.6216891407966614,
#   -0.2038697749376297,
#   0.1326010525226593,
#   0.3737781345844269,
#   0.9769270420074463,
#   -0.33806002140045166,
#   0.22809390723705292,
#   -0.35525697469711304,
#   -0.2613803744316101,
#   0.6527560949325562,
#   0.09034587442874908,
#   -0.40143316984176636,
#   0.02333563007414341,
#   -0.18595346808433533,
#   0.06381286680698395,
#   -0.0341019481420517,
#   5.418364889919758e-05,
#   -0.2970273494720459,
#   0.04208390414714813,
#   -0.0723641961812973,
#   -0.21242287755012512,
#   -0.41142719984054565,
#   -0.09453723579645157,
#   0.06064939498901367,
#   0.11535744369029999,
#   1.1331524848937988,
#   0.5678779482841492,
#   -0.09710336476564407,
#   -0.695778489112854,
#   0.7255798578262329,
#   -0.6104514598846436,
#   0.18310102820396423,
#   0.1203901544213295,
#   -0.2859594225883484,
#   -0.318293035030365,
#   0.4996880292892456,
#   -0.49229300022125244,
#   0.2755182385444641,
#   -0.11034509539604187,
#   -0.5609769225120544,
#   2.643700122833252,
#   -0.242810919880867,
#   -0.4668143093585968,
#   -0.024914592504501343,
#   0.008525870740413666,
#   0.0326705127954483,
#   -0.45701009035110474,
#   0.2355547547340393,
#   0.008039221167564392,
#   -0.06437279284000397,
#   0.2720195949077606,
#   -0.22220662236213684,
#   0.3829502463340759,
#   -0.3283980190753937,
#   -0.5289364457130432,
#   0.13401620090007782,
#   -0.11307094991207123,
#   -0.2108263224363327,
#   -0.04431735724210739,
#   -0.23887526988983154,
#   0.19810912013053894,
#   -0.3459997773170471]}

# %%
def gendata():
    for sample in dataset:
        assert "download_count" in sample
        assert "image_vector" in sample
        
        assert type(sample["download_count"]) == float
        assert np.array(sample["image_vector"]).shape == (512,)
        
        yield sample

# %%
from elasticsearch.helpers import parallel_bulk

for success, info in parallel_bulk(client=es, index="image-index", actions=gendata()):
    if not success:
        print('A document failed:', info)

# %% [markdown]
# ### Debug

# %%
# Load query vector
with open("query_vector.json", "r") as f:
    query_vector = json.load(f)["query_vector"]

# %%
# Inspect query vector type and shape
type(query_vector), np.array(query_vector).shape
# Out:
# (list, (512,))

# %%
# Assert query vector of 512-dim
assert np.array(query_vector).shape == (512,)

# %%
# Hybrid search

k = 20

resp = es.search(
    index=INDEX_NAME,
    size=k,
    query={"constant_score": {"filter": {"match_all": {}}, "boost": 1.0}},
    knn={
        "field": "image_vector",
        "query_vector": query_vector,
        "k": k,
        "num_candidates": 100,
    },
    explain=True
)

hits = resp.get("hits").get("hits")
df = pd.DataFrame(hits)

df = df[["_score", "_explanation"]]
df
# Out:
#       _score                                       _explanation
# 0   1.658169  {'value': 1.6581688, 'description': 'sum of:',...
# 1   1.651484  {'value': 1.651484, 'description': 'sum of:', ...
# 2   1.648651  {'value': 1.6486505, 'description': 'sum of:',...
# 3   1.646819  {'value': 1.6468188, 'description': 'sum of:',...
# 4   1.638959  {'value': 1.6389592, 'description': 'sum of:',...
# 5   1.638397  {'value': 1.6383975, 'description': 'sum of:',...
# 6   1.638098  {'value': 1.6380985, 'description': 'sum of:',...
# 7   1.637987  {'value': 1.6379869, 'description': 'sum of:',...
# 8   1.635532  {'value': 1.6355321, 'description': 'sum of:',...
# 9   1.635031  {'value': 1.6350307, 'description': 'sum of:',...
# 10  1.633245  {'value': 1.6332455, 'description': 'sum of:',...
# 11  1.632338  {'value': 1.6323383, 'description': 'sum of:',...
# 12  1.630140  {'value': 1.6301397, 'description': 'sum of:',...
# 13  1.000000  {'value': 1.0, 'description': 'sum of:', 'deta...
# 14  1.000000  {'value': 1.0, 'description': 'sum of:', 'deta...
# 15  1.000000  {'value': 1.0, 'description': 'sum of:', 'deta...
# 16  1.000000  {'value': 1.0, 'description': 'sum of:', 'deta...
# 17  1.000000  {'value': 1.0, 'description': 'sum of:', 'deta...
# 18  1.000000  {'value': 1.0, 'description': 'sum of:', 'deta...
# 19  1.000000  {'value': 1.0, 'description': 'sum of:', 'deta...

# %%
df["_explanation"].value_counts()
# Out:
# {'value': 1.0, 'description': 'sum of:', 'details': [{'value': 1.0, 'description': 'ConstantScore(*:*)', 'details': []}]}                                                                                         7
# {'value': 1.6581688, 'description': 'sum of:', 'details': [{'value': 0.65816873, 'description': 'within top k documents', 'details': []}, {'value': 1.0, 'description': 'ConstantScore(*:*)', 'details': []}]}    1
# {'value': 1.651484, 'description': 'sum of:', 'details': [{'value': 0.651484, 'description': 'within top k documents', 'details': []}, {'value': 1.0, 'description': 'ConstantScore(*:*)', 'details': []}]}       1
# {'value': 1.6486505, 'description': 'sum of:', 'details': [{'value': 1.0, 'description': 'ConstantScore(*:*)', 'details': []}]}                                                                                   1
# {'value': 1.6468188, 'description': 'sum of:', 'details': [{'value': 0.64681876, 'description': 'within top k documents', 'details': []}, {'value': 1.0, 'description': 'ConstantScore(*:*)', 'details': []}]}    1
# {'value': 1.6389592, 'description': 'sum of:', 'details': [{'value': 0.63895917, 'description': 'within top k documents', 'details': []}, {'value': 1.0, 'description': 'ConstantScore(*:*)', 'details': []}]}    1
# {'value': 1.6383975, 'description': 'sum of:', 'details': [{'value': 1.0, 'description': 'ConstantScore(*:*)', 'details': []}]}                                                                                   1
# {'value': 1.6380985, 'description': 'sum of:', 'details': [{'value': 1.0, 'description': 'ConstantScore(*:*)', 'details': []}]}                                                                                   1
# {'value': 1.6379869, 'description': 'sum of:', 'details': [{'value': 0.6379869, 'description': 'within top k documents', 'details': []}, {'value': 1.0, 'description': 'ConstantScore(*:*)', 'details': []}]}     1
# {'value': 1.6355321, 'description': 'sum of:', 'details': [{'value': 0.63553214, 'description': 'within top k documents', 'details': []}, {'value': 1.0, 'description': 'ConstantScore(*:*)', 'details': []}]}    1
# {'value': 1.6350307, 'description': 'sum of:', 'details': [{'value': 0.6350307, 'description': 'within top k documents', 'details': []}, {'value': 1.0, 'description': 'ConstantScore(*:*)', 'details': []}]}     1
# {'value': 1.6332455, 'description': 'sum of:', 'details': [{'value': 0.6332454, 'description': 'within top k documents', 'details': []}, {'value': 1.0, 'description': 'ConstantScore(*:*)', 'details': []}]}     1
# {'value': 1.6323383, 'description': 'sum of:', 'details': [{'value': 0.63233835, 'description': 'within top k documents', 'details': []}, {'value': 1.0, 'description': 'ConstantScore(*:*)', 'details': []}]}    1
# {'value': 1.6301397, 'description': 'sum of:', 'details': [{'value': 0.6301397, 'description': 'within top k documents', 'details': []}, {'value': 1.0, 'description': 'ConstantScore(*:*)', 'details': []}]}     1
# Name: _explanation, dtype: int64

# %%
# KNN search

k = 20

resp = es.search(
    index=INDEX_NAME,
    size=k,
    knn={
        "field": "image_vector",
        "query_vector": query_vector,
        "k": k,
        "num_candidates": 100,
    },
    explain=True
)

hits = resp.get("hits").get("hits")
df = pd.DataFrame(hits)

df = df[["_score", "_explanation"]]
df
# Out:
#       _score                                       _explanation
# 0   0.658169  {'value': 0.65816873, 'description': 'within t...
# 1   0.654055  {'value': 0.0, 'description': 'not in top k do...
# 2   0.651484  {'value': 0.651484, 'description': 'within top...
# 3   0.648651  {'value': 0.0, 'description': 'not in top k do...
# 4   0.647027  {'value': 0.0, 'description': 'not in top k do...
# 5   0.646819  {'value': 0.64681876, 'description': 'within t...
# 6   0.646349  {'value': 0.0, 'description': 'not in top k do...
# 7   0.641008  {'value': 0.0, 'description': 'not in top k do...
# 8   0.638959  {'value': 0.63895917, 'description': 'within t...
# 9   0.638397  {'value': 0.0, 'description': 'not in top k do...
# 10  0.638099  {'value': 0.0, 'description': 'not in top k do...
# 11  0.637987  {'value': 0.6379869, 'description': 'within to...
# 12  0.637876  {'value': 0.0, 'description': 'not in top k do...
# 13  0.636324  {'value': 0.0, 'description': 'not in top k do...
# 14  0.635532  {'value': 0.63553214, 'description': 'within t...
# 15  0.635031  {'value': 0.6350307, 'description': 'within to...
# 16  0.633245  {'value': 0.6332454, 'description': 'within to...
# 17  0.632338  {'value': 0.63233835, 'description': 'within t...
# 18  0.630140  {'value': 0.6301397, 'description': 'within to...
# 19  0.628156  {'value': 0.0, 'description': 'not in top k do...

# %%
df["_explanation"].value_counts()
# Out:
# {'value': 0.0, 'description': 'not in top k documents', 'details': []}           10
# {'value': 0.65816873, 'description': 'within top k documents', 'details': []}     1
# {'value': 0.651484, 'description': 'within top k documents', 'details': []}       1
# {'value': 0.64681876, 'description': 'within top k documents', 'details': []}     1
# {'value': 0.63895917, 'description': 'within top k documents', 'details': []}     1
# {'value': 0.6379869, 'description': 'within top k documents', 'details': []}      1
# {'value': 0.63553214, 'description': 'within top k documents', 'details': []}     1
# {'value': 0.6350307, 'description': 'within top k documents', 'details': []}      1
# {'value': 0.6332454, 'description': 'within top k documents', 'details': []}      1
# {'value': 0.63233835, 'description': 'within top k documents', 'details': []}     1
# {'value': 0.6301397, 'description': 'within top k documents', 'details': []}      1
# Name: _explanation, dtype: int64

# %%
# Constant score search

k = 20

resp = es.search(
    index=INDEX_NAME,
    size=k,
    query={"constant_score": {"filter": {"match_all": {}}, "boost": 1.0}},
    explain=True
)

hits = resp.get("hits").get("hits")
df = pd.DataFrame(hits)

df = df[["_score", "_explanation"]]
df
# Out:
#     _score                                       _explanation
# 0      1.0  {'value': 1.0, 'description': 'ConstantScore(*...
# 1      1.0  {'value': 1.0, 'description': 'ConstantScore(*...
# 2      1.0  {'value': 1.0, 'description': 'ConstantScore(*...
# 3      1.0  {'value': 1.0, 'description': 'ConstantScore(*...
# 4      1.0  {'value': 1.0, 'description': 'ConstantScore(*...
# 5      1.0  {'value': 1.0, 'description': 'ConstantScore(*...
# 6      1.0  {'value': 1.0, 'description': 'ConstantScore(*...
# 7      1.0  {'value': 1.0, 'description': 'ConstantScore(*...
# 8      1.0  {'value': 1.0, 'description': 'ConstantScore(*...
# 9      1.0  {'value': 1.0, 'description': 'ConstantScore(*...
# 10     1.0  {'value': 1.0, 'description': 'ConstantScore(*...
# 11     1.0  {'value': 1.0, 'description': 'ConstantScore(*...
# 12     1.0  {'value': 1.0, 'description': 'ConstantScore(*...
# 13     1.0  {'value': 1.0, 'description': 'ConstantScore(*...
# 14     1.0  {'value': 1.0, 'description': 'ConstantScore(*...
# 15     1.0  {'value': 1.0, 'description': 'ConstantScore(*...
# 16     1.0  {'value': 1.0, 'description': 'ConstantScore(*...
# 17     1.0  {'value': 1.0, 'description': 'ConstantScore(*...
# 18     1.0  {'value': 1.0, 'description': 'ConstantScore(*...
# 19     1.0  {'value': 1.0, 'description': 'ConstantScore(*...

# %%
df["_explanation"].value_counts()
# Out:
# {'value': 1.0, 'description': 'ConstantScore(*:*)', 'details': []}    20
# Name: _explanation, dtype: int64
